# %% [markdown]
# # Module 7 | Graphics

# %% [markdown]
# ### Basic graphics

# %%
countries <- c("Malaysia", "Singapore", "Thailand")
population <- c(0.3, 0.8, 0.6)

data <- data.frame(countries, population)
data
# Out:
#   countries population
# 1 Malaysia  0.3
# 2 Singapore 0.8
# 3 Thailand  0.6

# %%
plot(data$countries, data$population)
# Out:
# plot without title

# %%
plot(data$population)
# Out:
# plot without title
